# %% [markdown]
# # Mask R-CNN Training (AMPD)
#
# This notebook shows how to train Mask R-CNN on your own Artificial Manga Panel Dataset.

# %% [markdown]
# ## **1. Installation**

# %%
# %tensorflow_version 1.x
# !pip install --upgrade h5py==2.10.0
# !git clone https://github.com/seel-channel/AMPD_Mask_RCNN
# %matplotlib inline
# Out:
# TensorFlow 1.x selected.
# Collecting h5py==2.10.0
#   Downloading h5py-2.10.0-cp37-cp37m-manylinux1_x86_64.whl (2.9 MB)
#      |████████████████████████████████| 2.9 MB 5.2 MB/s
# Requirement already satisfied: six in /usr/local/lib/python3.7/dist-packages (from h5py==2.10.0) (1.15.0)
# Requirement already satisfied: numpy>=1.7 in /usr/local/lib/python3.7/dist-packages (from h5py==2.10.0) (1.19.5)
# Installing collected packages: h5py
#   Attempting uninstall: h5py
#     Found existing installation: h5py 3.1.0
#     Uninstalling h5py-3.1.0:
#       Successfully uninstalled h5py-3.1.0
# Successfully installed h5py-2.10.0
# Cloning into 'AMPD_Mask_RCNN'...
# remote: Enumerating objects: 1074, done.
# remote: Counting objects: 100% (21/21), done.
# remote: Compressing objects: 100% (17/17), done.
# remote: Total 1074 (delta 10), reused 11 (delta 4), pack-reused 1053
# Receiving objects: 100% (1074/1074), 125.88 MiB | 27.14 MiB/s, done.
# Resolving deltas: 100% (631/631), done.

# %%
import sys
sys.path.append("/content/AMPD_Mask_RCNN")
from train_mask_rcnn import *
# Out:
# VERS 0.2
# Using TensorFlow backend.
# Downloading pretrained model to /content/AMPD_Mask_RCNN/mask_rcnn_coco.h5 ...
# ... done downloading pretrained model!

# %% [markdown]
# ## **2. Run Mask-RCNN on Images**
#
# You can load here the image and extract the mask using Mask-RCNN

# %%
from google.colab import drive
drive.mount('/content/gdrive')
# Out:
# Mounted at /content/gdrive

# %%
# Load model
drive_folder = "/content/gdrive/MyDrive/ampd/"
model, inference_config = load_test_model(2, drive_folder + "/pretrained/")
# Out:
# Loading weights from  /content/gdrive/MyDrive/ampd//pretrained/object20211122T0339/mask_rcnn_object_0010.h5
# Re-starting from epoch 10

# %%
from mrcnn import visualize

# Load Image
img = cv2.imread("/content/images/Page_5.jpg")
image = cv2.cvtColor(img, cv2.COLOR_BGR2RGB)

# Detect results
r = model.detect([image])[0]
visualize.display_instances(image, r['rois'], r['masks'], r['class_ids'], 
                            ['BG', "speech_bubble", "panel"], r['scores'], show_bbox=False)
